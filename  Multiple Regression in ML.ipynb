# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read the Dataset
data=pd.read_csv("Toyota.csv", na_values=["??"])
data=data.dropna()
data
# Out:
#         Price   Age      KM FuelType   HP  MetColor Automatic      CC Doors  \
# 0      7450.0  65.0   82000   Petrol   86         1         0  1300.0     3
# 8      9950.0  65.0   65513   Petrol  110         1         1  1600.0  Four
# 9      7900.0  75.0  125400   Petrol  110         0         0  1600.0     3
# 10     6495.0  74.0   96302   Petrol   86         1         0  1300.0     3
# 11     9500.0  66.0   74963   Petrol  107         0         1  1600.0     3
# ...       ...   ...     ...      ...  ...       ...       ...     ...   ...
# 1441   8750.0  68.0  101889   petrol  110         1         0  1600.0     5
# 1442   9950.0  62.0  109547   petrol  110         0         0  1600.0     5
# 1443   9250.0  80.0   44444   Petrol  110         1         0  1600.0     3
# 1444  12450.0  54.0   46230   Petrol  110         1         0  1600.0     3
# 1445   8500.0  77.0   62285   Petrol  110         1         0  1600.0     5
#
#       Weight
# 0     1015.0
# 8     1070.0
# ...

# %%
# Split the data based on independent (x) and dependent variable (y)
x=data.iloc[:,1:3].values #x-features (Age,KM)
y=data.iloc[:,0:1].values #y-labels (price)

# %%
# Divide the complete dataset into training and test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#print(x_train)

# %%
# To create my model
# Regression Line on Train dataset
from sklearn.linear_model import LinearRegression
lrc=LinearRegression() #object
lrc.fit(x_train,y_train) #Training
# Out:
# LinearRegression()

# %%
print(lrc.coef_) #label(Predict)=intercept_ + coef1_ * 'Age' + coef2_ * 'KM'
print(lrc.intercept_)
# Out:
# [[-1.53172833e+02 -1.45265021e-02]]
# [20259.25376206]

# %%
predict=lrc.predict(x_test)
print(predict) #Predicted values of Price
print(y_test) #Actual Values of Price
# Out:
# [[ 7565.66795366]
#  [13321.30589296]
#  [19296.63725561]
#  [10903.76266982]
#  [10930.22456183]
#  [ 7178.4366445 ]
#  [ 7342.0071371 ]
#  [ 9041.04798534]
#  [ 8512.99676452]
#  [18361.75723659]
#  [11765.17469407]
#  [14104.90857692]
#  [11450.44018264]
#  [15962.33935137]
#  [ 9946.01793646]
#  [14060.99703959]
#  [13406.25687742]
#  [ 9335.07352008]
#  [ 7289.51541141]
#  [12452.2965081 ]
#  [11386.6758913 ]
#  [10952.52979561]
#  [ 5995.44023235]
#  [ 9135.56985609]
#  [ 8860.92309566]
#  [ 8973.60101547]
#  [15433.16958989]
#  [ 7737.80284668]
#  [10895.07747968]
#  [ 7270.08642505]
#  [13570.84754144]
#  [ 7165.9841159 ]
#  [ 9254.51659228]
#  [11074.64081018]
#  [ 7846.28179019]
#  [10632.37855702]
#  [18769.57052067]
#  [ 8950.06310761]
#  [11417.15996626]
#  [13546.50651875]
#  [12023.82280125]
#  [ 9752.30163567]
#  [ 9305.40458738]
#  [11835.53401738]
#  [15520.19454789]
#  [ 6699.32189309]
#  [ 9872.34657067]
#  [ 9857.70054025]
#  [11397.74508592]
#  [18211.19004201]
# ...

# %%
plt.scatter(y_test,predict)
plt.show()

# %%
plt.plot(y_test,predict,'r+')

# %%
#Find Accuracy of data

print("Accuracy of Fitting the Model:",lrc.score(x_test,predict))

print("Accuracy of Test Data:",lrc.score(x_test,y_test))

print("Accuracy of Train Data:",lrc.score(x_train,y_train))
# Out:
# Accuracy of Fitting the Model: 1.0
# Accuracy of Test Data: 0.7449290551636041
# Accuracy of Train Data: 0.8036604159781764
