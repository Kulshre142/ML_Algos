# %%
import numpy as np
import matplotlib.pyplot as plot
mean=0
std=0.1
array = np.random.normal(0,0.1,1000)
print(array)
# Out:
# [-0.01510988 -0.04346144 -0.07766164 -0.12733238  0.16141608  0.00623896
#  -0.00444069 -0.02634718  0.07485083  0.04485771  0.03872515  0.27715421
#   0.04823582 -0.14048817  0.06161259 -0.12666498  0.06099753  0.18719826
#   0.02497892  0.08210462 -0.09847217 -0.0132351  -0.00260457  0.05677328
#  -0.00118797  0.25319543 -0.11145421  0.0873472  -0.03709165  0.06046911
#  -0.16594198 -0.04474725  0.02382697 -0.01360573 -0.1320628   0.05177003
#   0.23541663 -0.24406198  0.09089968 -0.10699587 -0.07565284 -0.00962223
#  -0.02489406 -0.1252958   0.14954525 -0.01043339 -0.09023288 -0.02599797
#  -0.1432039  -0.21764064  0.03440729 -0.01171829 -0.04726741 -0.08815009
#   0.04153755  0.08126997  0.16723618  0.09929844 -0.01115509 -0.05375669
#  -0.09548181  0.00948177  0.06155252  0.07440462 -0.04155449  0.01241807
#  -0.12727668  0.1330572   0.04906072 -0.0122644  -0.05539834  0.0348976
#  -0.10857717  0.02144506 -0.18894297 -0.0529486  -0.12230976 -0.00074983
# ...

# %%
print(array.mean())
print(array.std())
# Out:
# 0.004745946888565294
# 0.10237127292681052

# %%
#simple hist
import numpy as np
import matplotlib.pyplot as plt
array=np.random.randint(1,100,150)
plt.hist(array)
plt.show()

# %% [raw]
# import numpy as np
# import matplotlib.pyplot as plt
# plt.hist(array.rwidth=0.05)
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plot
array=np.random.randint(1,100,100)
bins=[0,25,50,75,100]
plt.xsticks
plt.hist(array)
plt.show()

# %%
import numpy as np
x=np.random.randn(100,1)
y=np.random.randn(500,1)
plt.hist(x,bins=20,label="histogram1",alpha=0.2)
plt.hist(y,bins=20,label="histogram1",alpha=0.2)
plt.legend(loc="best")
plt.show()

# %%
import pandas as pd
data= pd.read_csv("Toyota.csv", na_values=["??"])
print(data)
# Out:
#         Price   Age      KM FuelType   HP  MetColor Automatic      CC  Doors  \
# 0      7450.0  65.0   82000   Petrol   86         1         0  1300.0      3
# 1         NaN  74.0     NaN   Petrol   ##         1         0     NaN      3
# 2      8950.0  80.0   64000      NaN  110         0      ####  1600.0  Three
# 3     11450.0  54.0     NaN   Petrol  NaN         0         0     NaN      5
# 4         NaN  42.0      ##   Petrol  110         1         0  1600.0    NaN
# ...       ...   ...     ...      ...  ...       ...       ...     ...    ...
# 1441   8750.0  68.0  101889   petrol  110         1         0  1600.0      5
# 1442   9950.0  62.0  109547   petrol  110         0         0  1600.0      5
# 1443   9250.0  80.0   44444   Petrol  110         1         0  1600.0      3
# 1444  12450.0  54.0   46230   Petrol  110         1         0  1600.0      3
# 1445   8500.0  77.0   62285   Petrol  110         1         0  1600.0      5
#
#       Weight
# 0     1015.0
# 1     1050.0
# ...

# %%
x=data['Price']
bins=np.arrange(min(dat['Price']),max(data['Price']),5000)
print(bins)
plt.hist(x,bins,color='green',label='histogram')
plt.xlabel('Price',labelpad=20,wight='bold',size=12)
plt.xticks([4350,9350,14350,19350,29350])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-08be967569bf> in <module>
#       1 x=data['Price']
# ----> 2 bins=np.arange(min(dat['Price']),max(data['Price']),5000)
#       3 print(bins)
#       4 plt.hist(x,bins,color='green',label='histogram')
#       5 plt.xlabel('Price',labelpad=20,wight='bold',size=12)
#
# NameError: name 'dat' is not defined
